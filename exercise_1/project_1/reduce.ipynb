# %% [markdown]
# # Reduce Benchmark

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('reduce_thin_results/thin_reduce_results.csv')

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))

# List of algorithms to plot
algorithms = ['basic_linear', 'chain', 'pipeline']

for algo in algorithms:
    # Filtering data for each algorithm
    filtered_data = data[data['Algorithm'] == algo]
    # Plotting each algorithm's latency vs. processes
    ax.plot(filtered_data['Processes'].unique(), filtered_data.groupby('Processes')['Latency'].mean(), label=algo)

ax.set_title('Latency by Number of Processes for Each Algorithm')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Average Latency (ms)')
ax.legend()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
#plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('reduce_thin_results/thin_reduce_results.csv')

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))

# Filtering data for the "basic_linear" algorithm
filtered_data = data[data['Algorithm'] == 'basic_linear']

# Plotting latency vs. processes for "basic_linear"
ax.plot(filtered_data['Processes'].unique(), filtered_data.groupby('Processes')['Latency'].mean(), label='Basic Linear', marker='o', color='blue')

ax.set_title('Latency by Number of Processes for Basic Linear Algorithm')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Average Latency (ms)')
ax.legend()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('reduce_thin_results/thin_reduce_results.csv')

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))

# Filtering data for the "basic_linear" algorithm
filtered_data = data[data['Algorithm'] == 'chain']

# Plotting latency vs. processes for "basic_linear"
ax.plot(filtered_data['Processes'].unique(), filtered_data.groupby('Processes')['Latency'].mean(), label='Chain', marker='o', color='orange')


ax.set_title('Latency by Number of Processes for Chain Algorithm')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Average Latency (ms)')
ax.legend()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('reduce_thin_results/thin_reduce_results.csv')

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))

# Filtering data for the "basic_linear" algorithm
filtered_data = data[data['Algorithm'] == 'pipeline']

# Plotting latency vs. processes for "basic_linear"
ax.plot(filtered_data['Processes'].unique(), filtered_data.groupby('Processes')['Latency'].mean(), label='Pipeline', marker='o', color='green')

ax.set_title('Latency by Number of Processes for Pipeline Algorithm')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Average Latency (ms)')
ax.legend()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
plt.show()

# %% [markdown]
# # Latency by process for each message size for `linear` algorithm

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('reduce_thin_results/thin_reduce_results.csv')

# Filter data for the "basic_linear" algorithm
filtered_data = data[data['Algorithm'] == 'basic_linear']

# Plotting the data
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique sizes and sort them
sizes = sorted(filtered_data['Size'].unique())

# Generate a color map
cm = plt.get_cmap('rainbow')
ax.set_prop_cycle('color', [cm(1. * i / len(sizes)) for i in range(len(sizes))])

for size in sizes:
    # Filter data for each size
    size_data = filtered_data[filtered_data['Size'] == size]
    # Plotting latency vs. processes for each size
    ax.plot(size_data['Processes'], size_data['Latency'], label=f'Size {size} bytes', marker='o')

ax.set_title('Latency by Number of Processes for Each Message Size (Linear Algorithm)')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Latency (ms)')
ax.legend(title="Message Size", bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
#plt.yscale('log')
plt.show()

# %% [markdown]
# # Latency by processes for each message size for `chain` algorithm

# %%
# Filter data for the "chain" algorithm
filtered_data = data[data['Algorithm'] == 'chain']
basic_linear_data = data[data['Algorithm'] == 'basic_linear']

# Plotting the data
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique sizes and sort them
sizes = sorted(filtered_data['Size'].unique())

# Generate a color map
cm = plt.get_cmap('rainbow')
ax.set_prop_cycle('color', [cm(1. * i / len(sizes)) for i in range(len(sizes))])

for size in sizes:
    # Filter data for each size
    size_data = filtered_data[filtered_data['Size'] == size]
    basic_size_data = basic_linear_data[basic_linear_data['Size'] == size]
    # Plotting latency vs. processes for each size
    ax.plot(size_data['Processes'], size_data['Latency'], label=f'Size {size} bytes', marker='o')
    ax.plot(basic_size_data['Processes'], basic_size_data['Latency'], marker='o', color='lightgray')

ax.set_title('Latency by Number of Processes for Each Message Size (Chain Algorithm)')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Latency (ms)')
ax.legend(title="Message Size", bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
#plt.yscale('log')
plt.show()

# %% [markdown]
# # Latency by processes for each message size for `pipeline` algorithm

# %%
# Filter data for the "pipeline" algorithm
filtered_data = data[data['Algorithm'] == 'pipeline']
basic_linear_data = data[data['Algorithm'] == 'basic_linear']

# Plotting the data
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique sizes and sort them
sizes = sorted(filtered_data['Size'].unique())

# Generate a color map
cm = plt.get_cmap('rainbow')
ax.set_prop_cycle('color', [cm(1. * i / len(sizes)) for i in range(len(sizes))])

for size in sizes:
    # Filter data for each size
    size_data = filtered_data[filtered_data['Size'] == size]
    basic_size_data = basic_linear_data[basic_linear_data['Size'] == size]

    # Plotting latency vs. processes for each size
    ax.plot(size_data['Processes'], size_data['Latency'], label=f'Size {size} bytes', marker='o')
    ax.plot(basic_size_data['Processes'], basic_size_data['Latency'], marker='o', color='lightgray')

ax.set_title('Latency by Number of Processes for Each Message Size (Pipeline Algorithm)')
ax.set_xlabel('Number of Processes')
ax.set_ylabel('Latency (ms)')
ax.legend(title="Message Size", bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout()
plt.axvline(x=24, color='red', linestyle='--')
plt.axvline(x=12, color='gray', linestyle='--')
plt.axvline(x=36, color='gray', linestyle='--')
#plt.yscale('log')
plt.show()

# %%
import pwlf
import numpy as np
import pandas as pd

data = pd.read_csv('reduce_thin_results/thin_reduce_results.csv')

def fit_and_plot(data, algorithm):
    # Filter data for the specific algorithm
    filtered_data = data[data['Algorithm'] == algorithm]

    # Get unique process counts and sort them
    x = filtered_data['Processes'].unique()
    x.sort()

    # Calculate mean latency for each process count
    y = filtered_data.groupby('Processes')['Latency'].mean().values

    # Initialize piecewise linear fit with your x and y data
    my_pwlf = pwlf.PiecewiseLinFit(x, y)

    # Define breakpoints at every 12 cores, adjusting as necessary
    breaks = [x[0]] + [b for b in x if b % 12 == 0 and b != x[0]] + [x[-1]]

    # Fit the model with predefined breaks
    res = my_pwlf.fit_with_breaks(breaks)

    # Predict for the entire range
    x_hat = np.linspace(min(x), max(x), 100)
    y_hat = my_pwlf.predict(x_hat)

    # Plotting
    plt.scatter(x, y, label=f'Actual Data - {algorithm}')
    plt.plot(x_hat, y_hat, label=f'Segmented Model - {algorithm}')

    return my_pwlf

plt.figure(figsize=(12, 8))

# List of algorithms to analyze
algorithms = ['pipeline', 'chain', 'basic_linear']

# Loop through each algorithm and apply the fitting and plotting function
for alg in algorithms:
    my_pwlf = fit_and_plot(data, alg)
    # print the model parameters
    print(f"Model parameters for {alg}:")
    # print(f""my_pwlf.fit_breaks)
    print(f"Slope: {my_pwlf.slopes}")
    print(f"Intercept: {my_pwlf.intercepts}")

    # print the model
    print(f"Model: Latency = {my_pwlf.intercepts[0]:.4f} + {my_pwlf.slopes[0]:.4f}*Processes, for Processes <= {my_pwlf.fit_breaks[1]}")
    print(f"Model: Latency = {my_pwlf.intercepts[1]:.4f} + {my_pwlf.slopes[1]:.4f}*Processes, for Processes <= {my_pwlf.fit_breaks[2]}")
    print(f"Model: Latency = {my_pwlf.intercepts[2]:.4f} + {my_pwlf.slopes[2]:.4f}*Processes, for Processes <= {my_pwlf.fit_breaks[3]}")
    print(f"Model: Latency = {my_pwlf.intercepts[3]:.4f} + {my_pwlf.slopes[3]:.4f}*Processes, for Processes <= {my_pwlf.fit_breaks[4]}")

plt.title('Segmented Linear Model Fits to Latency Data by Number of Processes for All Algorithms')
plt.xlabel('Number of Processes')
plt.ylabel('Latency (μsec)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pwlf/pwlf.py:1113: RuntimeWarning: invalid value encountered in divide
#   self.slopes = np.divide(
# Model parameters for pipeline:
# Slope: [13.62580365 11.54440845 12.30037826 12.60422795         nan]
# Intercept: [-19.03075038   5.94599212 -12.19728345 -23.13587237          nan]
# Model: Latency = -19.0308 + 13.6258*Processes, for Processes <= 12
# Model: Latency = 5.9460 + 11.5444*Processes, for Processes <= 24
# Model: Latency = -12.1973 + 12.3004*Processes, for Processes <= 36
# Model: Latency = -23.1359 + 12.6042*Processes, for Processes <= 48
# Model parameters for chain:
# Slope: [3.43604714 2.43501506 2.69073288 2.52940637        nan]
# Intercept: [15.71891334 27.73129827 21.59407081 27.40182499         nan]
# Model: Latency = 15.7189 + 3.4360*Processes, for Processes <= 12
# Model: Latency = 27.7313 + 2.4350*Processes, for Processes <= 24
# Model: Latency = 21.5941 + 2.6907*Processes, for Processes <= 36
# Model: Latency = 27.4018 + 2.5294*Processes, for Processes <= 48
# Model parameters for basic_linear:
# Slope: [ 8.80706821 10.62424667  6.32763855  6.86103253         nan]
# Intercept: [ -5.57515166 -27.38129311  75.73730175  56.53511827          nan]
# Model: Latency = -5.5752 + 8.8071*Processes, for Processes <= 12
# Model: Latency = -27.3813 + 10.6242*Processes, for Processes <= 24
# Model: Latency = 75.7373 + 6.3276*Processes, for Processes <= 36
# Model: Latency = 56.5351 + 6.8610*Processes, for Processes <= 48
